# %%
import cowsay

cowsay.turkey("Gobble Gobble, assholes.")
# Out:
#   ________________________
# < Gobble Gobble, assholes. >
# ...
#                              \
#                               \
#                                \
#                                 \
#                                                                   ,+*^^*+___+++_
#                                                             ,*^^^^              )
#                                                          _+*                     ^**+_
#                                                        +^       _ _++*+_+++_,         )
#                                    _+^^*+_    (     ,+*^ ^          \+_        )
#                                   {       )  (    ,(    ,_+--+--,      ^)      ^\
#                                  { (\@)    } f   ,(  ,+-^ __*_*_  ^^\_   ^\       )
#                                 {:;-/    (_+*-+^^^^^+*+*<_ _++_)_    )    )      /
#                                ( /  (    (        ,___    ^*+_+* )   <    <      \
# ...
